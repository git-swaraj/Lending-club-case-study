# %% [markdown]
# # Lending Club Case study using Exploratory Data Analysis
# ## Swaraj , Gagan Chhabra
# ### ML C67 batch

# %%
#Import required packages and set options to be used in this notebook
import pandas as pd
import numpy as np
import seaborn as sns
import datetime as dt
import warnings
import matplotlib.pyplot as plt

# %%
# Suppress the warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set options for better display of notebook output
#
pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 100)
sns.set()

# %%
# Read the loan dataset into a pandas dataframe
loan_df = pd.read_csv('/content/drive/MyDrive/lendigclub/loan.csv')

# %% [markdown]
# #### Preview the data to ensure that the data has been loaded correctly
#  - Ensure that there are no header rows present
#  - Esnure that there are no summary or total rows present

# %%
loan_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000          4975.00   36 months
# 1  1077430    1314167       2500         2500          2500.00   60 months
# 2  1077175    1313524       2400         2400          2400.00   36 months
# 3  1076863    1277178      10000        10000         10000.00   36 months
# 4  1075358    1311748       3000         3000          3000.00   60 months
#
#   int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0   10.65%       162.87     B        B2                       NaN  10+ years
# 1   15.27%        59.83     C        C4                     Ryder   < 1 year
# 2   15.96%        84.33     C        C5                       NaN  10+ years
# 3   13.49%       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4   12.69%        67.79     B        B5  University Medical Group     1 year
#
#   home_ownership  annual_inc verification_status issue_d  loan_status  \
# 0           RENT    24000.00            Verified  Dec-11   Fully Paid
# 1           RENT    30000.00     Source Verified  Dec-11  Charged Off
# 2           RENT    12252.00        Not Verified  Dec-11   Fully Paid
# 3           RENT    49200.00     Source Verified  Dec-11   Fully Paid
# 4           RENT    80000.00     Source Verified  Dec-11      Current
#
#   pymnt_plan                                                url  \
# 0          n  https://lendingclub.com/browse/loanDetail.acti...
# 1          n  https://lendingclub.com/browse/loanDetail.acti...
# 2          n  https://lendingclub.com/browse/loanDetail.acti...
# 3          n  https://lendingclub.com/browse/loanDetail.acti...
# 4          n  https://lendingclub.com/browse/loanDetail.acti...
#
#                                                 desc         purpose  \
# 0    Borrower added on 12/22/11 > I need to upgra...     credit_card
# 1    Borrower added on 12/22/11 > I plan to use t...             car
# 2                                                NaN  small_business
# 3    Borrower added on 12/21/11 > to pay for prop...           other
# 4    Borrower added on 12/21/11 > I plan on combi...           other
#
#                   title zip_code addr_state   dti  delinq_2yrs  \
# 0              Computer    860xx         AZ 27.65            0
# 1                  bike    309xx         GA  1.00            0
# 2  real estate business    606xx         IL  8.72            0
# 3              personel    917xx         CA 20.00            0
# 4              Personal    972xx         OR 17.94            0
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0           Jan-85               1                     NaN
# 1           Apr-99               5                     NaN
# 2           Nov-01               2                     NaN
# 3           Feb-96               1                   35.00
# 4           Jan-96               0                   38.00
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         3        0      13648     83.70%          9
# 1                     NaN         3        0       1687      9.40%          4
# 2                     NaN         2        0       2956     98.50%         10
# 3                     NaN        10        0       5598        21%         37
# 4                     NaN        15        0      27783     53.90%         38
#
#   initial_list_status  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  \
# 0                   f       0.00           0.00      5863.16          5833.84
# 1                   f       0.00           0.00      1008.71          1008.71
# 2                   f       0.00           0.00      3005.67          3005.67
# 3                   f       0.00           0.00     12231.89         12231.89
# 4                   f     524.06         524.06      3513.33          3513.33
#
#    total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# 0          5000.00         863.16                0.00        0.00
# 1           456.46         435.17                0.00      117.08
# 2          2400.00         605.67                0.00        0.00
# 3         10000.00        2214.92               16.97        0.00
# 4          2475.94        1037.39                0.00        0.00
#
#    collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d  \
# 0                     0.00       Jan-15           171.62          NaN
# 1                     1.11       Apr-13           119.66          NaN
# 2                     0.00       Jun-14           649.91          NaN
# 3                     0.00       Jan-15           357.48          NaN
# 4                     0.00       May-16            67.79       Jun-16
#
#   last_credit_pull_d  collections_12_mths_ex_med  mths_since_last_major_derog  \
# 0             May-16                        0.00                          NaN
# 1             Sep-13                        0.00                          NaN
# 2             May-16                        0.00                          NaN
# 3             Apr-16                        0.00                          NaN
# 4             May-16                        0.00                          NaN
#
#    policy_code application_type  annual_inc_joint  dti_joint  \
# 0            1       INDIVIDUAL               NaN        NaN
# 1            1       INDIVIDUAL               NaN        NaN
# 2            1       INDIVIDUAL               NaN        NaN
# 3            1       INDIVIDUAL               NaN        NaN
# 4            1       INDIVIDUAL               NaN        NaN
#
#    verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  \
# 0                        NaN               0           NaN          NaN
# 1                        NaN               0           NaN          NaN
# 2                        NaN               0           NaN          NaN
# 3                        NaN               0           NaN          NaN
# 4                        NaN               0           NaN          NaN
#
#    open_acc_6m  open_il_6m  open_il_12m  open_il_24m  mths_since_rcnt_il  \
# 0          NaN         NaN          NaN          NaN                 NaN
# 1          NaN         NaN          NaN          NaN                 NaN
# 2          NaN         NaN          NaN          NaN                 NaN
# 3          NaN         NaN          NaN          NaN                 NaN
# 4          NaN         NaN          NaN          NaN                 NaN
#
#    total_bal_il  il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  \
# 0           NaN      NaN          NaN          NaN         NaN       NaN
# 1           NaN      NaN          NaN          NaN         NaN       NaN
# 2           NaN      NaN          NaN          NaN         NaN       NaN
# 3           NaN      NaN          NaN          NaN         NaN       NaN
# 4           NaN      NaN          NaN          NaN         NaN       NaN
#
#    total_rev_hi_lim  inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  \
# 0               NaN     NaN          NaN           NaN                   NaN
# 1               NaN     NaN          NaN           NaN                   NaN
# 2               NaN     NaN          NaN           NaN                   NaN
# 3               NaN     NaN          NaN           NaN                   NaN
# 4               NaN     NaN          NaN           NaN                   NaN
#
#    avg_cur_bal  bc_open_to_buy  bc_util  chargeoff_within_12_mths  \
# 0          NaN             NaN      NaN                      0.00
# 1          NaN             NaN      NaN                      0.00
# 2          NaN             NaN      NaN                      0.00
# 3          NaN             NaN      NaN                      0.00
# 4          NaN             NaN      NaN                      0.00
#
#    delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# 0            0                 NaN                   NaN
# 1            0                 NaN                   NaN
# 2            0                 NaN                   NaN
# 3            0                 NaN                   NaN
# 4            0                 NaN                   NaN
#
#    mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 0                    NaN             NaN       NaN                   NaN
# 1                    NaN             NaN       NaN                   NaN
# 2                    NaN             NaN       NaN                   NaN
# 3                    NaN             NaN       NaN                   NaN
# 4                    NaN             NaN       NaN                   NaN
#
#    mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    NaN
# 4                       NaN                    NaN
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                    NaN             NaN
# 1                             NaN                    NaN             NaN
# 2                             NaN                    NaN             NaN
# 3                             NaN                    NaN             NaN
# 4                             NaN                    NaN             NaN
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              NaN          NaN        NaN        NaN            NaN
# 1              NaN          NaN        NaN        NaN            NaN
# 2              NaN          NaN        NaN        NaN            NaN
# 3              NaN          NaN        NaN        NaN            NaN
# 4              NaN          NaN        NaN        NaN            NaN
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            NaN                  NaN       NaN               NaN
# 1            NaN                  NaN       NaN               NaN
# 2            NaN                  NaN       NaN               NaN
# 3            NaN                  NaN       NaN               NaN
# 4            NaN                  NaN       NaN               NaN
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           NaN                 NaN                 NaN             NaN
# 1           NaN                 NaN                 NaN             NaN
# 2           NaN                 NaN                 NaN             NaN
# 3           NaN                 NaN                 NaN             NaN
# 4           NaN                 NaN                 NaN             NaN
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               NaN                  0.00       0.00              NaN
# 1               NaN                  0.00       0.00              NaN
# 2               NaN                  0.00       0.00              NaN
# 3               NaN                  0.00       0.00              NaN
# 4               NaN                  0.00       0.00              NaN
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit
# 0                NaN             NaN                         NaN
# 1                NaN             NaN                         NaN
# 2                NaN             NaN                         NaN
# 3                NaN             NaN                         NaN
# 4                NaN             NaN                         NaN

# %%
loan_df.tail()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 39712  92187      92174       2500         2500          1075.00   36 months
# 39713  90665      90607       8500         8500           875.00   36 months
# 39714  90395      90390       5000         5000          1325.00   36 months
# 39715  90376      89243       5000         5000           650.00   36 months
# 39716  87023      86999       7500         7500           800.00   36 months
#
#       int_rate  installment grade sub_grade                   emp_title  \
# 39712    8.07%        78.42     A        A4             FiSite Research
# 39713   10.28%       275.38     C        C1  Squarewave Solutions, Ltd.
# 39714    8.07%       156.84     A        A4                         NaN
# 39715    7.43%       155.38     A        A2                         NaN
# 39716   13.75%       255.43     E        E2            Evergreen Center
#
#       emp_length home_ownership  annual_inc verification_status issue_d  \
# 39712    4 years       MORTGAGE   110000.00        Not Verified  Jul-07
# 39713    3 years           RENT    18000.00        Not Verified  Jul-07
# 39714   < 1 year       MORTGAGE   100000.00        Not Verified  Jul-07
# 39715   < 1 year       MORTGAGE   200000.00        Not Verified  Jul-07
# 39716   < 1 year            OWN    22000.00        Not Verified  Jun-07
#
#       loan_status pymnt_plan  \
# 39712  Fully Paid          n
# 39713  Fully Paid          n
# 39714  Fully Paid          n
# 39715  Fully Paid          n
# 39716  Fully Paid          n
#
#                                                      url  \
# 39712  https://lendingclub.com/browse/loanDetail.acti...
# 39713  https://lendingclub.com/browse/loanDetail.acti...
# 39714  https://lendingclub.com/browse/loanDetail.acti...
# 39715  https://lendingclub.com/browse/loanDetail.acti...
# 39716  https://lendingclub.com/browse/loanDetail.acti...
#
#                                                     desc             purpose  \
# 39712  Our current gutter system on our home is old a...    home_improvement
# 39713  The rate of interest and fees incurred by carr...         credit_card
# 39714                                                NaN  debt_consolidation
# 39715                                                NaN               other
# 39716  I plan to consolidate over $7,000 of debt: a c...  debt_consolidation
#
#                            title zip_code addr_state   dti  delinq_2yrs  \
# 39712           Home Improvement    802xx         CO 11.33            0
# 39713  Retiring credit card debt    274xx         NC  6.40            1
# 39714     MBA Loan Consolidation    017xx         MA  2.30            0
# 39715                   JAL Loan    208xx         MD  3.72            0
# 39716         Consolidation Loan    027xx         MA 14.29            1
#
#       earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 39712           Nov-90               0                    0.00
# 39713           Dec-86               1                    5.00
# 39714           Oct-98               0                    0.00
# 39715           Nov-88               0                    0.00
# 39716           Oct-03               0                   11.00
#
#        mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  \
# 39712                    0.00        13        0       7274     13.10%
# 39713                    0.00         6        0       8847     26.90%
# 39714                    0.00        11        0       9698     19.40%
# 39715                    0.00        17        0      85607      0.70%
# 39716                    0.00         7        0       4175     51.50%
#
#        total_acc initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# 39712         40                   f       0.00           0.00      2822.97
# 39713          9                   f       0.00           0.00      9913.49
# 39714         20                   f       0.00           0.00      5272.16
# 39715         26                   f       0.00           0.00      5174.20
# 39716          8                   f       0.00           0.00      9195.26
#
#        total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 39712          1213.88          2500.00         322.97                0.00
# 39713          1020.51          8500.00        1413.49                0.00
# 39714          1397.12          5000.00         272.16                0.00
# 39715           672.66          5000.00         174.20                0.00
# 39716           980.83          7500.00        1695.26                0.00
#
#        recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 39712        0.00                     0.00       Jul-10            80.90
# 39713        0.00                     0.00       Jul-10           281.94
# 39714        0.00                     0.00       Apr-08             0.00
# 39715        0.00                     0.00       Jan-08             0.00
# 39716        0.00                     0.00       Jun-10           256.59
#
#       next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 39712          NaN             Jun-10                         NaN
# 39713          NaN             Jul-10                         NaN
# 39714          NaN             Jun-07                         NaN
# 39715          NaN             Jun-07                         NaN
# 39716          NaN             Jun-10                         NaN
#
#        mths_since_last_major_derog  policy_code application_type  \
# 39712                          NaN            1       INDIVIDUAL
# 39713                          NaN            1       INDIVIDUAL
# 39714                          NaN            1       INDIVIDUAL
# 39715                          NaN            1       INDIVIDUAL
# 39716                          NaN            1       INDIVIDUAL
#
#        annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  \
# 39712               NaN        NaN                        NaN               0
# 39713               NaN        NaN                        NaN               0
# 39714               NaN        NaN                        NaN               0
# 39715               NaN        NaN                        NaN               0
# 39716               NaN        NaN                        NaN               0
#
#        tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  \
# 39712           NaN          NaN          NaN         NaN          NaN
# 39713           NaN          NaN          NaN         NaN          NaN
# 39714           NaN          NaN          NaN         NaN          NaN
# 39715           NaN          NaN          NaN         NaN          NaN
# 39716           NaN          NaN          NaN         NaN          NaN
#
#        open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 39712          NaN                 NaN           NaN      NaN          NaN
# 39713          NaN                 NaN           NaN      NaN          NaN
# 39714          NaN                 NaN           NaN      NaN          NaN
# 39715          NaN                 NaN           NaN      NaN          NaN
# 39716          NaN                 NaN           NaN      NaN          NaN
#
#        open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 39712          NaN         NaN       NaN               NaN     NaN
# 39713          NaN         NaN       NaN               NaN     NaN
# 39714          NaN         NaN       NaN               NaN     NaN
# 39715          NaN         NaN       NaN               NaN     NaN
# 39716          NaN         NaN       NaN               NaN     NaN
#
#        total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 39712          NaN           NaN                   NaN          NaN
# 39713          NaN           NaN                   NaN          NaN
# 39714          NaN           NaN                   NaN          NaN
# 39715          NaN           NaN                   NaN          NaN
# 39716          NaN           NaN                   NaN          NaN
#
#        bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 39712             NaN      NaN                       NaN            0
# 39713             NaN      NaN                       NaN            0
# 39714             NaN      NaN                       NaN            0
# 39715             NaN      NaN                       NaN            0
# 39716             NaN      NaN                       NaN            0
#
#        mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 39712                 NaN                   NaN                    NaN
# 39713                 NaN                   NaN                    NaN
# 39714                 NaN                   NaN                    NaN
# 39715                 NaN                   NaN                    NaN
# 39716                 NaN                   NaN                    NaN
#
#        mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 39712             NaN       NaN                   NaN
# 39713             NaN       NaN                   NaN
# 39714             NaN       NaN                   NaN
# 39715             NaN       NaN                   NaN
# 39716             NaN       NaN                   NaN
#
#        mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 39712                       NaN                    NaN
# 39713                       NaN                    NaN
# 39714                       NaN                    NaN
# 39715                       NaN                    NaN
# 39716                       NaN                    NaN
#
#        mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 39712                             NaN                    NaN             NaN
# 39713                             NaN                    NaN             NaN
# 39714                             NaN                    NaN             NaN
# 39715                             NaN                    NaN             NaN
# 39716                             NaN                    NaN             NaN
#
#        num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 39712              NaN          NaN        NaN        NaN            NaN
# 39713              NaN          NaN        NaN        NaN            NaN
# 39714              NaN          NaN        NaN        NaN            NaN
# 39715              NaN          NaN        NaN        NaN            NaN
# 39716              NaN          NaN        NaN        NaN            NaN
#
#        num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 39712            NaN                  NaN       NaN               NaN
# 39713            NaN                  NaN       NaN               NaN
# 39714            NaN                  NaN       NaN               NaN
# 39715            NaN                  NaN       NaN               NaN
# 39716            NaN                  NaN       NaN               NaN
#
#        num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 39712           NaN                 NaN                 NaN             NaN
# 39713           NaN                 NaN                 NaN             NaN
# 39714           NaN                 NaN                 NaN             NaN
# 39715           NaN                 NaN                 NaN             NaN
# 39716           NaN                 NaN                 NaN             NaN
#
#        percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 39712               NaN                   NaN        NaN              NaN
# 39713               NaN                   NaN        NaN              NaN
# 39714               NaN                   NaN        NaN              NaN
# 39715               NaN                   NaN        NaN              NaN
# 39716               NaN                   NaN        NaN              NaN
#
#        total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit
# 39712                NaN             NaN                         NaN
# 39713                NaN             NaN                         NaN
# 39714                NaN             NaN                         NaN
# 39715                NaN             NaN                         NaN
# 39716                NaN             NaN                         NaN

# %% [markdown]
# #### Get a basic understanding of the loan data frame like size and data types

# %%
print(loan_df.shape)
loan_df.info()
# Out:
# (39717, 111)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %% [markdown]
# # Data handling and cleaning

# %% [markdown]
# #### Check if there are any null values in the dataset

# %%
# Get the total row count to estimate percentage of missing values in dataset
total_num_of_rows = len(loan_df)
print(total_num_of_rows)
# Out:
# 39717

# %%
# Percentage of null values in each column
round(loan_df.isna().sum(axis=0) / total_num_of_rows * 100 , 2)
# Out:
# id                             0.00
# member_id                      0.00
# loan_amnt                      0.00
# funded_amnt                    0.00
# funded_amnt_inv                0.00
#                               ...
# tax_liens                      0.10
# tot_hi_cred_lim              100.00
# total_bal_ex_mort            100.00
# total_bc_limit               100.00
# total_il_high_credit_limit   100.00
# Length: 111, dtype: float64

# %% [markdown]
# #### Based on the basic analysis we could observe that there are multiple columns with null values
# ####  Drop all null valued columns as they are not useful for analysis and load it into new data frame

# %%
# Drop all null columns
loans = loan_df.dropna(axis=1, how='all')
loans.shape
# Out:
# (39717, 57)

# %%
# Validate the remaining data
round(loans.isna().sum(axis=0) / total_num_of_rows * 100 , 2)
# Out:
# id                            0.00
# member_id                     0.00
# loan_amnt                     0.00
# funded_amnt                   0.00
# funded_amnt_inv               0.00
# term                          0.00
# int_rate                      0.00
# installment                   0.00
# grade                         0.00
# sub_grade                     0.00
# emp_title                     6.19
# emp_length                    2.71
# home_ownership                0.00
# annual_inc                    0.00
# verification_status           0.00
# issue_d                       0.00
# loan_status                   0.00
# pymnt_plan                    0.00
# url                           0.00
# desc                         32.59
# purpose                       0.00
# title                         0.03
# zip_code                      0.00
# addr_state                    0.00
# dti                           0.00
# delinq_2yrs                   0.00
# earliest_cr_line              0.00
# inq_last_6mths                0.00
# mths_since_last_delinq       64.66
# mths_since_last_record       92.99
# open_acc                      0.00
# pub_rec                       0.00
# revol_bal                     0.00
# revol_util                    0.13
# total_acc                     0.00
# initial_list_status           0.00
# out_prncp                     0.00
# out_prncp_inv                 0.00
# total_pymnt                   0.00
# total_pymnt_inv               0.00
# total_rec_prncp               0.00
# total_rec_int                 0.00
# total_rec_late_fee            0.00
# recoveries                    0.00
# collection_recovery_fee       0.00
# last_pymnt_d                  0.18
# last_pymnt_amnt               0.00
# next_pymnt_d                 97.13
# last_credit_pull_d            0.01
# collections_12_mths_ex_med    0.14
# policy_code                   0.00
# application_type              0.00
# acc_now_delinq                0.00
# chargeoff_within_12_mths      0.14
# delinq_amnt                   0.00
# pub_rec_bankruptcies          1.75
# tax_liens                     0.10
# dtype: float64

# %%
# There are columns with significant null values
# removing columns with more than 30% (i.e. 70% data available) of values as null
loans.dropna(thresh = len(loans) * .7 , axis=1, inplace=True)
loans.shape
# Out:
# (39717, 53)

# %%
#Looking at the number of unique values
loans.nunique().sort_values().head(20)
# Out:
# tax_liens                      1
# delinq_amnt                    1
# chargeoff_within_12_mths       1
# acc_now_delinq                 1
# application_type               1
# policy_code                    1
# collections_12_mths_ex_med     1
# initial_list_status            1
# pymnt_plan                     1
# term                           2
# pub_rec_bankruptcies           3
# verification_status            3
# loan_status                    3
# pub_rec                        5
# home_ownership                 5
# grade                          7
# inq_last_6mths                 9
# delinq_2yrs                   11
# emp_length                    11
# purpose                       14
# dtype: int64

# %%
# There are multiple columns in the dataset that has single values which will not help in analysis
# Dropping single valued columns
loans.drop(['tax_liens','delinq_amnt','chargeoff_within_12_mths','acc_now_delinq','application_type','policy_code','collections_12_mths_ex_med','initial_list_status','pymnt_plan'], axis=1, inplace=True)
loans.shape
# Out:
# (39717, 44)

# %%
loans.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000          4975.00   36 months
# 1  1077430    1314167       2500         2500          2500.00   60 months
# 2  1077175    1313524       2400         2400          2400.00   36 months
# 3  1076863    1277178      10000        10000         10000.00   36 months
# 4  1075358    1311748       3000         3000          3000.00   60 months
#
#   int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0   10.65%       162.87     B        B2                       NaN  10+ years
# 1   15.27%        59.83     C        C4                     Ryder   < 1 year
# 2   15.96%        84.33     C        C5                       NaN  10+ years
# 3   13.49%       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4   12.69%        67.79     B        B5  University Medical Group     1 year
#
#   home_ownership  annual_inc verification_status issue_d  loan_status  \
# 0           RENT    24000.00            Verified  Dec-11   Fully Paid
# 1           RENT    30000.00     Source Verified  Dec-11  Charged Off
# 2           RENT    12252.00        Not Verified  Dec-11   Fully Paid
# 3           RENT    49200.00     Source Verified  Dec-11   Fully Paid
# 4           RENT    80000.00     Source Verified  Dec-11      Current
#
#                                                  url         purpose  \
# 0  https://lendingclub.com/browse/loanDetail.acti...     credit_card
# 1  https://lendingclub.com/browse/loanDetail.acti...             car
# 2  https://lendingclub.com/browse/loanDetail.acti...  small_business
# 3  https://lendingclub.com/browse/loanDetail.acti...           other
# 4  https://lendingclub.com/browse/loanDetail.acti...           other
#
#                   title zip_code addr_state   dti  delinq_2yrs  \
# 0              Computer    860xx         AZ 27.65            0
# 1                  bike    309xx         GA  1.00            0
# 2  real estate business    606xx         IL  8.72            0
# 3              personel    917xx         CA 20.00            0
# 4              Personal    972xx         OR 17.94            0
#
#   earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal revol_util  \
# 0           Jan-85               1         3        0      13648     83.70%
# 1           Apr-99               5         3        0       1687      9.40%
# 2           Nov-01               2         2        0       2956     98.50%
# 3           Feb-96               1        10        0       5598        21%
# 4           Jan-96               0        15        0      27783     53.90%
#
#    total_acc  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  \
# 0          9       0.00           0.00      5863.16          5833.84
# 1          4       0.00           0.00      1008.71          1008.71
# 2         10       0.00           0.00      3005.67          3005.67
# 3         37       0.00           0.00     12231.89         12231.89
# 4         38     524.06         524.06      3513.33          3513.33
#
#    total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# 0          5000.00         863.16                0.00        0.00
# 1           456.46         435.17                0.00      117.08
# 2          2400.00         605.67                0.00        0.00
# 3         10000.00        2214.92               16.97        0.00
# 4          2475.94        1037.39                0.00        0.00
#
#    collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  \
# 0                     0.00       Jan-15           171.62             May-16
# 1                     1.11       Apr-13           119.66             Sep-13
# 2                     0.00       Jun-14           649.91             May-16
# 3                     0.00       Jan-15           357.48             Apr-16
# 4                     0.00       May-16            67.79             May-16
#
#    pub_rec_bankruptcies
# 0                  0.00
# 1                  0.00
# 2                  0.00
# 3                  0.00
# 4                  0.00

# %% [markdown]
# Based on the understanding from data dictionary and the preview of data
# - id, member_id, url have unique values for each row and doesn't add value to the analysis
# - total_rec_int, total_rec_prncp, total_rec_late_fee, recoveries, collection_recovery_fee, last_credit_pull_d, earliest_cr_line,nlast_pymnt_d, out_prncp, out_prncp_inv columns are valid for borrowers who already took the loan. we are interested only in new loan applications
# - recoveries, collection_recovery_fee columns are valid for charged off loans and not influencing the outcomes.
# - funded_amnt_inv, total_pymnt_inv are from investors perspective and not a driving factor for analysis
# - addr_state can be used in place of zip_code for analysis
# - emp_title has large number of unique values and cannot help in a meaningful analysis
# - title columns is redundant with the purpose column based on the values
# The above columns can be removed for this analysis

# %%
remove_cols = ['id', 'member_id', 'url', 'total_rec_int', 'earliest_cr_line', 'total_rec_prncp', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_credit_pull_d', 'last_pymnt_d', 'out_prncp', 'out_prncp_inv', 'recoveries', 'collection_recovery_fee', 'funded_amnt_inv', 'total_pymnt_inv', 'zip_code', 'emp_title', 'title']
loans.drop(remove_cols, axis=1, inplace=True)
loans.shape
# Out:
# (39717, 26)

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             39717 non-null  int64
#  1   funded_amnt           39717 non-null  int64
#  2   term                  39717 non-null  object
#  3   int_rate              39717 non-null  object
#  4   installment           39717 non-null  float64
#  5   grade                 39717 non-null  object
#  6   sub_grade             39717 non-null  object
#  7   emp_length            38642 non-null  object
#  8   home_ownership        39717 non-null  object
#  9   annual_inc            39717 non-null  float64
#  10  verification_status   39717 non-null  object
#  11  issue_d               39717 non-null  object
#  12  loan_status           39717 non-null  object
#  13  purpose               39717 non-null  object
#  14  addr_state            39717 non-null  object
#  15  dti                   39717 non-null  float64
#  16  delinq_2yrs           39717 non-null  int64
#  17  inq_last_6mths        39717 non-null  int64
#  18  open_acc              39717 non-null  int64
#  19  pub_rec               39717 non-null  int64
#  20  revol_bal             39717 non-null  int64
#  21  revol_util            39667 non-null  object
#  22  total_acc             39717 non-null  int64
#  23  total_pymnt           39717 non-null  float64
#  24  last_pymnt_amnt       39717 non-null  float64
#  25  pub_rec_bankruptcies  39020 non-null  float64
# dtypes: float64(6), int64(8), object(12)
# memory usage: 7.9+ MB

# %%
# Current loans cannot be analysed to decide on the probability of Default
# Remove the rows that have loan_status as Current
loans = loans[loans.loan_status != 'Current']
loans.shape
# Out:
# (38577, 26)

# %% [markdown]
# ### Handling missing values

# %%
loans.pub_rec_bankruptcies.isna().sum() / len(loans) * 100
# Out:
# 1.8067760582730643

# %%
loans.revol_util.isna().sum() / len(loans) * 100
# Out:
# 0.12961090805402184

# %%
# revol_util , pub_rec_bankruptcies has very less null values which cannot be imputated due to nature of the data
# drop the rows with null values
loans.dropna(subset=['revol_util', 'pub_rec_bankruptcies'], axis=0, inplace=True)
loans.shape
# Out:
# (37830, 26)

# %%
# Check for the percentage of data after removing for missing values
round(len(loans) / total_num_of_rows * 100, 2)
# Out:
# 95.25

# %%
# There is still 95% of the original data available for analysis

# %%
# emp_length still has missing values and could be useful for analysis
loans.emp_length.value_counts()
# Out:
# emp_length
# 10+ years    8368
# < 1 year     4329
# 2 years      4202
# 3 years      3947
# 4 years      3290
# 5 years      3157
# 1 year       3071
# 6 years      2133
# 7 years      1686
# 8 years      1408
# 9 years      1209
# Name: count, dtype: int64

# %%
# The most frequent value for emp_length is 10+ years,
# Since the missing values are not too many records, imputing the missing values with mode value of emp_length
loans.emp_length.fillna(loans.emp_length.mode()[0], inplace=True)
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37830 entries, 0 to 39680
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             37830 non-null  int64
#  1   funded_amnt           37830 non-null  int64
#  2   term                  37830 non-null  object
#  3   int_rate              37830 non-null  object
#  4   installment           37830 non-null  float64
#  5   grade                 37830 non-null  object
#  6   sub_grade             37830 non-null  object
#  7   emp_length            37830 non-null  object
#  8   home_ownership        37830 non-null  object
#  9   annual_inc            37830 non-null  float64
#  10  verification_status   37830 non-null  object
#  11  issue_d               37830 non-null  object
#  12  loan_status           37830 non-null  object
#  13  purpose               37830 non-null  object
#  14  addr_state            37830 non-null  object
#  15  dti                   37830 non-null  float64
#  16  delinq_2yrs           37830 non-null  int64
#  17  inq_last_6mths        37830 non-null  int64
#  18  open_acc              37830 non-null  int64
#  19  pub_rec               37830 non-null  int64
#  20  revol_bal             37830 non-null  int64
#  21  revol_util            37830 non-null  object
#  22  total_acc             37830 non-null  int64
#  23  total_pymnt           37830 non-null  float64
#  24  last_pymnt_amnt       37830 non-null  float64
#  25  pub_rec_bankruptcies  37830 non-null  float64
# dtypes: float64(6), int64(8), object(12)
# memory usage: 7.8+ MB

# %%
loans.head()
# Out:
#    loan_amnt  funded_amnt        term int_rate  installment grade sub_grade  \
# 0       5000         5000   36 months   10.65%       162.87     B        B2
# 1       2500         2500   60 months   15.27%        59.83     C        C4
# 2       2400         2400   36 months   15.96%        84.33     C        C5
# 3      10000        10000   36 months   13.49%       339.31     C        C1
# 5       5000         5000   36 months    7.90%       156.46     A        A4
#
#   emp_length home_ownership  annual_inc verification_status issue_d  \
# 0  10+ years           RENT    24000.00            Verified  Dec-11
# 1   < 1 year           RENT    30000.00     Source Verified  Dec-11
# 2  10+ years           RENT    12252.00        Not Verified  Dec-11
# 3  10+ years           RENT    49200.00     Source Verified  Dec-11
# 5    3 years           RENT    36000.00     Source Verified  Dec-11
#
#    loan_status         purpose addr_state   dti  delinq_2yrs  inq_last_6mths  \
# 0   Fully Paid     credit_card         AZ 27.65            0               1
# 1  Charged Off             car         GA  1.00            0               5
# 2   Fully Paid  small_business         IL  8.72            0               2
# 3   Fully Paid           other         CA 20.00            0               1
# 5   Fully Paid         wedding         AZ 11.20            0               3
#
#    open_acc  pub_rec  revol_bal revol_util  total_acc  total_pymnt  \
# 0         3        0      13648     83.70%          9      5863.16
# 1         3        0       1687      9.40%          4      1008.71
# 2         2        0       2956     98.50%         10      3005.67
# 3        10        0       5598        21%         37     12231.89
# 5         9        0       7963     28.30%         12      5632.21
#
#    last_pymnt_amnt  pub_rec_bankruptcies
# 0           171.62                  0.00
# 1           119.66                  0.00
# 2           649.91                  0.00
# 3           357.48                  0.00
# 5           161.03                  0.00

# %% [markdown]
# ### Standardizing the values
# - int_rate , revol_util are numeric float value, % sign to be removed

# %%
loans.int_rate = loans.int_rate.apply(lambda x : float(x.strip('%')))
loans.revol_util = loans.revol_util.apply(lambda x : float(x.strip('%')))

# %% [markdown]
# ### Derive additional information

# %%
# Extract the numeric part of experience (<1 year is assumed as zero and >10 is assumed as 10 for easy binning)
loans['emp_tenure'] = pd.to_numeric(loans.emp_length.apply(lambda x: 0 if "<" in x else (x.split('+')[0] if "+" in x else x.split()[0])))

# %%
# Calculate loan to income ratio
loans['l_to_i_ratio'] = round(loans.loan_amnt/loans.annual_inc,2)

# Extract the year from loan issue_d
loans['issue_y'] = loans.issue_d.apply(lambda x : dt.datetime.strptime(x, '%b-%y').year)

# Extract the month from loan issue_d
loans['issue_m'] = loans.issue_d.apply(lambda x : dt.datetime.strptime(x, '%b-%y').month)

# %%
# Group customer employment as Junior (0-3), Middle (4-7), Senior (8-10+) positions
loans['emp_postn'] = pd.cut(x=loans.emp_tenure, bins=[0,3,7,10], labels=['Junior','Middle','Senior'], right=True)
loans.emp_postn.value_counts()
# Out:
# emp_postn
# Senior    12015
# Junior    11220
# Middle    10266
# Name: count, dtype: int64

# %%
# Group customers by income levels as Low Income, Medium Income, High Income
loans.annual_inc.describe()
# Out:
# count     37830.00
# mean      68795.68
# std       63569.07
# min        4000.00
# 25%       40137.09
# 50%       59000.00
# 75%       82000.00
# max     6000000.00
# Name: annual_inc, dtype: float64

# %%
# Data distribution indicates presents of outliers, explore the range of outliers using box plot
sns.boxplot(x=loans.annual_inc)
plt.show()

# %%
# Determine the percentile of outliers
loans.annual_inc.quantile([0.5, 0.75,0.90, 0.95, 0.97,0.98, 0.99])
# Out:
# 0.50    59000.00
# 0.75    82000.00
# 0.90   115000.00
# 0.95   140004.00
# 0.97   165000.00
# 0.98   186000.00
# 0.99   234000.00
# Name: annual_inc, dtype: float64

# %%
# OUtliers are above the 97th percentile, remove them
loans = loans[loans.annual_inc <= loans.annual_inc.quantile(0.97)]
loans.shape
# Out:
# (36709, 31)

# %%
# Group customer by income groups as Low Income, Lower Middle Income, Middle Income, Upper Middle Income, High Income Groups
loans['inc_group'] = pd.qcut(loans.annual_inc, q=5, labels=['LIG','LMIG','MIG', 'UMIG', 'HIG'])
loans.inc_group.value_counts()
# Out:
# inc_group
# MIG     7575
# LMIG    7543
# LIG     7487
# HIG     7340
# UMIG    6764
# Name: count, dtype: int64

# %%
# Reset the index
#loans = loans.reset_index(drop=True)

# %%
loans.head()
# Out:
#    loan_amnt  funded_amnt        term  int_rate  installment grade sub_grade  \
# 0       5000         5000   36 months     10.65       162.87     B        B2
# 1       2500         2500   60 months     15.27        59.83     C        C4
# 2       2400         2400   36 months     15.96        84.33     C        C5
# 3      10000        10000   36 months     13.49       339.31     C        C1
# 5       5000         5000   36 months      7.90       156.46     A        A4
#
#   emp_length home_ownership  annual_inc verification_status issue_d  \
# 0  10+ years           RENT    24000.00            Verified  Dec-11
# 1   < 1 year           RENT    30000.00     Source Verified  Dec-11
# 2  10+ years           RENT    12252.00        Not Verified  Dec-11
# 3  10+ years           RENT    49200.00     Source Verified  Dec-11
# 5    3 years           RENT    36000.00     Source Verified  Dec-11
#
#    loan_status         purpose addr_state   dti  delinq_2yrs  inq_last_6mths  \
# 0   Fully Paid     credit_card         AZ 27.65            0               1
# 1  Charged Off             car         GA  1.00            0               5
# 2   Fully Paid  small_business         IL  8.72            0               2
# 3   Fully Paid           other         CA 20.00            0               1
# 5   Fully Paid         wedding         AZ 11.20            0               3
#
#    open_acc  pub_rec  revol_bal  revol_util  total_acc  total_pymnt  \
# 0         3        0      13648       83.70          9      5863.16
# 1         3        0       1687        9.40          4      1008.71
# 2         2        0       2956       98.50         10      3005.67
# 3        10        0       5598       21.00         37     12231.89
# 5         9        0       7963       28.30         12      5632.21
#
#    last_pymnt_amnt  pub_rec_bankruptcies  emp_tenure  l_to_i_ratio  issue_y  \
# 0           171.62                  0.00          10          0.21     2011
# 1           119.66                  0.00           0          0.08     2011
# 2           649.91                  0.00          10          0.20     2011
# 3           357.48                  0.00          10          0.20     2011
# 5           161.03                  0.00           3          0.14     2011
#
#    issue_m emp_postn inc_group
# 0       12    Senior       LIG
# 1       12       NaN       LIG
# 2       12    Senior       LIG
# 3       12    Senior      LMIG
# 5       12    Junior       LIG

# %% [markdown]
# ## Univariate Analysis

# %%
sns.reset_orig()
sns.set_palette('pastel', n_colors=7)
sns.countplot(x = 'loan_status', data = loans)
plt.show()

# %%
plt.style.use('ggplot')
loans.home_ownership.value_counts().plot.pie()
plt.show()

# %%
sns.countplot(loans.term)
plt.show()

# %%
sns.set_palette('icefire')
sns.histplot(loans.loan_amnt)
plt.show()

# %%
sns.set_palette('colorblind', n_colors=7)
sns.histplot(loans.annual_inc)
plt.show()

# %%
# Create datasets based on loan status for comparison
defaulted_loans = loans[loans.loan_status == 'Charged Off']
print(defaulted_loans.shape)

paid_up_loans = loans[loans.loan_status == 'Fully Paid']
print(paid_up_loans.shape)
# Out:
# (5377, 32)
# (31332, 32)

# %%
defaulted_loans.head()
# Out:
#     loan_amnt  funded_amnt        term  int_rate  installment grade sub_grade  \
# 1        2500         2500   60 months     15.27        59.83     C        C4
# 8        5600         5600   60 months     21.28       152.39     F        F2
# 9        5375         5375   60 months     12.69       121.45     B        B5
# 12       9000         9000   36 months     13.49       305.38     C        C1
# 14      10000        10000   36 months     10.65       325.74     B        B2
#
#    emp_length home_ownership  annual_inc verification_status issue_d  \
# 1    < 1 year           RENT    30000.00     Source Verified  Dec-11
# 8     4 years            OWN    40000.00     Source Verified  Dec-11
# 9    < 1 year           RENT    15000.00            Verified  Dec-11
# 12   < 1 year           RENT    30000.00     Source Verified  Dec-11
# 14    3 years           RENT   100000.00     Source Verified  Dec-11
#
#     loan_status             purpose addr_state   dti  delinq_2yrs  \
# 1   Charged Off                 car         GA  1.00            0
# 8   Charged Off      small_business         CA  5.55            0
# 9   Charged Off               other         TX 18.08            0
# 12  Charged Off  debt_consolidation         VA 10.08            0
# 14  Charged Off               other         CA  7.06            0
#
#     inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 1                5         3        0       1687        9.40          4
# 8                2        11        0       5210       32.60         13
# 9                0         2        0       9279       36.50          3
# 12               1         4        0      10452       91.70          9
# 14               2        14        0      11997       55.50         29
#
#     total_pymnt  last_pymnt_amnt  pub_rec_bankruptcies  emp_tenure  \
# 1       1008.71           119.66                  0.00           0
# 8        646.02           152.39                  0.00           4
# 9       1476.19           121.45                  0.00           0
# 12      2270.70           305.38                  0.00           0
# 14      7471.99           325.74                  0.00           3
#
#     l_to_i_ratio  issue_y  issue_m emp_postn inc_group
# 1           0.08     2011       12       NaN       LIG
# 8           0.14     2011       12    Middle      LMIG
# 9           0.36     2011       12       NaN       LIG
# 12          0.30     2011       12       NaN       LIG
# 14          0.10     2011       12    Junior       HIG

# %%
sns.countplot(x=defaulted_loans.inc_group)
plt.show()

# %%
sns.countplot(x=paid_up_loans.inc_group)
plt.show()

# %%
sns.set_palette('flare')
fig, ax = plt.subplots(figsize = (12,8))
sns.countplot(loans.purpose)
plt.show()

# %%
sns.set_palette('colorblind')
plt.figure(figsize=(15,15))
plt.subplot(221)
sns.countplot(x=defaulted_loans.issue_m)
plt.subplot(222)
sns.countplot(x=defaulted_loans.issue_y)
plt.subplot(223)
sns.countplot(x=paid_up_loans.issue_m)
plt.subplot(224)
sns.countplot(x=paid_up_loans.issue_y)
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.set_palette('colorblind')
plt.figure(figsize=(15,15))
plt.subplot(221)
sns.boxplot(x=loans.inc_group, y=loans.loan_amnt, hue=loans.loan_status, gap=0.1)
plt.subplot(222)
sns.boxplot(x=loans.emp_postn, y=loans.loan_amnt, hue=loans.loan_status, gap=0.1)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.set_palette('colorblind')
sns.histplot(x=loans.addr_state, hue=loans.loan_status, kde=True, multiple="dodge", shrink=1)
plt.show()

# %%
sns.reset_orig()
sns.set_palette('pastel', n_colors=7)
sns.countplot(x = 'verification_status', data = loans, hue= loans.loan_status)
plt.show()

# %%
sns.set_palette('colorblind')
#plt.figure(figsize=(25,15))
sns.histplot(x=loans.l_to_i_ratio, bins = 20, multiple="dodge", hue=loans.loan_status, kde=True)
plt.show()

# %%
sns.set_palette('colorblind')
#plt.figure(figsize=(25,15))
sns.histplot(x=loans.int_rate, bins = 20, multiple="dodge", hue=loans.loan_status, kde=True)
plt.show()

# %%
sns.set_palette('dark')
#plt.figure(figsize=(25,15))
sns.histplot(x=loans.revol_util, bins = 20, multiple="dodge", hue=loans.loan_status, kde=True)
plt.show()

# %%
sns.set_palette('Pastel1')
sns.countplot(y = 'purpose', data = loans, hue= loans.loan_status)
plt.show()

# %%
sns.set_palette('Pastel2')
plt.figure(figsize=(20,5))
plt.subplot(121)
sns.boxplot(x=loans.home_ownership, y=loans.loan_amnt)
plt.subplot(122)
sns.boxplot(x=loans.verification_status, y=loans.loan_amnt, order = loans.verification_status.unique())
plt.show()

# %%
sns.set_palette('Pastel2')
plt.figure(figsize=(15,6))
sns.barplot(x=defaulted_loans.loan_status, y=defaulted_loans.purpose, hue=defaulted_loans.purpose)
plt.show()

# %%
sns.set_palette('Pastel2')
plt.figure(figsize=(15,6))
sns.barplot(x=paid_up_loans.loan_status, y=paid_up_loans.purpose, hue=paid_up_loans.purpose)
plt.show()

# %% [markdown]
# ## Correlation analysis

# %%
sns.set_palette('colorblind')
sns.jointplot(x=defaulted_loans.open_acc, y=defaulted_loans.pub_rec)
sns.jointplot(x=paid_up_loans.open_acc, y=paid_up_loans.pub_rec)
plt.show()

# %%
loans.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'term', 'int_rate', 'installment', 'grade',
#        'sub_grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'purpose',
#        'addr_state', 'dti', 'delinq_2yrs', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'total_pymnt',
#        'last_pymnt_amnt', 'pub_rec_bankruptcies', 'emp_tenure', 'l_to_i_ratio',
#        'issue_y', 'issue_m', 'emp_postn', 'inc_group'],
#       dtype='object')

# %%
sns.pairplot(defaulted_loans[['open_acc', 'total_acc','pub_rec', 'inq_last_6mths', 'emp_tenure']])
plt.show()

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36709 entries, 0 to 39680
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             36709 non-null  int64
#  1   funded_amnt           36709 non-null  int64
#  2   term                  36709 non-null  object
#  3   int_rate              36709 non-null  float64
#  4   installment           36709 non-null  float64
#  5   grade                 36709 non-null  object
#  6   sub_grade             36709 non-null  object
#  7   emp_length            36709 non-null  object
#  8   home_ownership        36709 non-null  object
#  9   annual_inc            36709 non-null  float64
#  10  verification_status   36709 non-null  object
#  11  issue_d               36709 non-null  object
#  12  loan_status           36709 non-null  object
#  13  purpose               36709 non-null  object
#  14  addr_state            36709 non-null  object
#  15  dti                   36709 non-null  float64
#  16  delinq_2yrs           36709 non-null  int64
#  17  inq_last_6mths        36709 non-null  int64
#  18  open_acc              36709 non-null  int64
#  19  pub_rec               36709 non-null  int64
#  20  revol_bal             36709 non-null  int64
#  21  revol_util            36709 non-null  float64
#  22  total_acc             36709 non-null  int64
#  23  total_pymnt           36709 non-null  float64
#  24  last_pymnt_amnt       36709 non-null  float64
#  25  pub_rec_bankruptcies  36709 non-null  float64
#  26  emp_tenure            36709 non-null  int64
#  27  l_to_i_ratio          36709 non-null  float64
#  28  issue_y               36709 non-null  int64
#  29  issue_m               36709 non-null  int64
#  30  emp_postn             32474 non-null  category
#  31  inc_group             36709 non-null  category
# dtypes: category(2), float64(9), int64(11), object(10)
# memory usage: 8.8+ MB

# %%
numeric_cols = ['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti', 'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'revol_bal', 'revol_util', 'total_acc', 'total_pymnt','issue_y','issue_m', 'last_pymnt_amnt', 'l_to_i_ratio','emp_tenure','pub_rec_bankruptcies']

# %%
plt.figure(figsize=(20,20))
sns.heatmap(loans[numeric_cols].corr(),cmap='Greens', annot=True)
plt.show()

# %% [markdown]
# # Conclusions
# ## Based on the Exploratory Analysis of given data, we could infer that
#
# - ### Borrowers who have a loan to income ratio of more than 30% are very likely to default
# - ### Borrowers having high rate of revolving utilization are likely to default
# - ### Loans taken for purposes Debt Consolidation, Credit Card, Small Business and Other are very likely to default
# - ### Borrowers with employment tenure over have a risk of default
# - ### Borrowers with over 100K annual income are likely to default compared to lower income group
# - ### There is no relationship between the non demographic data and the risk of default
